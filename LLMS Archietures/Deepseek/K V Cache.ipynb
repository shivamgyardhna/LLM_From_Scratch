# %% [markdown]
# # In K-V(key-value) caching we caching the key and value of multihead attention so that inference time will be less but there is increase in store size due to the caching
# ### we can campare GPT with and without having K-V cache for their inference time to predict the output
