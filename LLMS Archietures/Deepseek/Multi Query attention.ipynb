# %% [markdown]
# # In Multi Query attention Differeny attention block will have same key,value weight matrix but different query matrix
# ### we can campare between GPT(as multi-head attention) and florea(as Multi query attention) and see their time and perfomace
