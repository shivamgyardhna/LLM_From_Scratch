# %% [markdown]
# # In Group Query attention Group of attention block will have same key,value weight matrix but different query matrix
# ### we can campare between GPT(as multi-head attention) and Llamma3(as Group query attention) and see their time and perfomace
